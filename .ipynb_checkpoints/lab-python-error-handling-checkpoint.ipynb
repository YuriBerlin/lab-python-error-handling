# %% [markdown]
# # Lab | Error Handling

# %% [markdown]
# ## Exercise: Error Handling for Managing Customer Orders
#
# The implementation of your code for managing customer orders assumes that the user will always enter a valid input.
#
# For example, we could modify the `initialize_inventory` function to include error handling.
#    - If the user enters an invalid quantity (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the quantity for that product.
#    - Use a try-except block to handle the error and continue prompting the user until a valid quantity is entered.
#
# ```python
# # Step 1: Define the function for initializing the inventory with error handling
# def initialize_inventory(products):
#     inventory = {}
#     for product in products:
#         valid_quantity = False
#         while not valid_quantity:
#             try:
#                 quantity = int(input(f"Enter the quantity of {product}s available: "))
#                 if quantity < 0:
#                     raise ValueError("Invalid quantity! Please enter a non-negative value.")
#                 valid_quantity = True
#             except ValueError as error:
#                 print(f"Error: {error}")
#         inventory[product] = quantity
#     return inventory
#
# # Or, in another way:
#
# def initialize_inventory(products):
#     inventory = {}
#     for product in products:
#         valid_input = False
#         while not valid_input:
#             try:
#                 quantity = int(input(f"Enter the quantity of {product}s available: "))
#                 if quantity >= 0:
#                     inventory[product] = quantity
#                     valid_input = True
#                 else:
#                     print("Quantity cannot be negative. Please enter a valid quantity.")
#             except ValueError:
#                 print("Invalid input. Please enter a valid quantity.")
#     return inventory
# ```
#
# Let's enhance your code by implementing error handling to handle invalid inputs.
#
# Follow the steps below to complete the exercise:
#
# 2. Modify the `calculate_total_price` function to include error handling.
#    - If the user enters an invalid price (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the price for that product.
#    - Use a try-except block to handle the error and continue prompting the user until a valid price is entered.
#
# 3. Modify the `get_customer_orders` function to include error handling.
#    - If the user enters an invalid number of orders (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the number of orders.
#    - If the user enters an invalid product name (e.g., a product name that is not in the inventory), or that doesn't have stock available, display an error message and ask them to re-enter the product name. *Hint: you will need to pass inventory as a parameter*
#    - Use a try-except block to handle the error and continue prompting the user until a valid product name is entered.
#
# 4. Test your code by running the program and deliberately entering invalid quantities and product names. Make sure the error handling mechanism works as expected.

# %%
products = ["hat", "key", "bag"]

# %%
def initialize_inventory(products):
    inventory = {}
    for product in products:
        valid_quantity = False
        while not valid_quantity:
            try:
                quantity = input(f"Enter the quantity of {product}s available: ")
                try:
                    int_quantity = int(quantity)
                except:
                    raise TypeError("Invalid quantity! Please enter a numerical value.")
                if int_quantity <0:
                    raise ValueError("Invalid quantity! Please enter a non-negative value.")
                valid_quantity = True
            except ValueError as error:
                print(f"ValueError: {error}")
            except TypeError as error:
                print(f"TypeError: {error}")
        inventory[product] = int_quantity
    return inventory

# %%
def get_customer_orders(inventory):
    """Getting orders. Output - set."""
    customer_orders = {}
    choice = 1
    while choice == 1:
        valid_item = False
        while not valid_item:

            x = input("\nPlease enter a product you would like to purchase: ")
            try:
                if x not in inventory:
                    raise ValueError("Please enter an item from the list.")
                elif x in inventory and inventory[x]==0:
                    raise ValueError("Sorry, this item is sold out. Please choose any other item")
                else:
                    valid_number = False
                    while valid_number == False:
                        try:
                            y = input(f"\nPlease enter a number of {x}s you would like to purchase: ")
                            try:
                                y = int(y)
                            except:
                                raise TypeError("Please enter a numerical value.")
                            if y <= 0:
                                raise ValueError("Please enter a positive number.")
                            if y > inventory[x]:
                                raise ValueError("Sorry, amount of items in store is not sufficient.")
                            customer_orders[x]=y
                            print ("Added")
                            valid_number = True
                        except ValueError as error:
                            print(f"ValueError: {error}") 
                        except TypeError as error:
                            print(f"TypeError: {error}")    
                valid_item = True
            except ValueError as error:
                    print(f"ValueError: {error}") 
                      
            
            
        choice = int(input("\nDo you want to choose an other product, 1 - yes, 0 - no: "))
    return customer_orders

# %%
def update_inventory(customer_orders, inventory):
    """Updating inventory after customer orders."""
    inv =  inventory
    for i in inv.keys():
         if inv[i] > 0 and (i in customer_orders):
            inv[i] =  inv[i]-customer_orders[i]
    return inv

# %%
def calculate_order_statistics (products, customer_orders):
    total = len(customer_orders)
    percent = round(len(customer_orders)/len(inventory)*100,2)
    return (total, percent)

# %%
def calculate_total_price (customer_orders):
    price_list = []
    for i in customer_orders.keys():
        valid_number = False
        while valid_number == False:
            try:
                price = input(f"\nEnter a price for one {i}: ")
                try:
                    price = int(price)
                except:
                    raise TypeError ("Please enter a numerical value")
                if price < 0:
                    raise ValueError ("Please enter a non-negative value")
                valid_number = True
                price_list.append(price)
            except ValueError as error:
                print(f"ValueError: {error}") 
            except TypeError as error:
                print(f"TypeError: {error}")    
    return (sum(price_list))

# %%
def print_order_statistics (order_statistics):
    print ("\n\n")
    print(f"Total number of products ordered:  {order_statistics[0]}")
    print(f"Percentage of unique products ordered:  {order_statistics[1]}")

# %%
def print_updated_inventory(inventory):
    print ("\n\n")
    print ("Updated inventory:")
    print (inventory)

# %%
inventory = initialize_inventory (products)
customer_orders = get_customer_orders(inventory)
price = calculate_total_price(customer_orders)
print(f"\n\nTotal price: {price}")
updated_iventory = dict()
updated_inventory = update_inventory(customer_orders, inventory)
order_stats = calculate_order_statistics(products, customer_orders)
print_order_statistics(order_stats)
print_updated_inventory(updated_inventory)
# Out:
# Enter the quantity of hats available: 1
# Enter the quantity of keys available: 2
# Enter the quantity of bags available: 3
#
# Please enter a product you would like to purchase: bag
#
# Please enter a number of bags you would like to purchase: 1
# Added
#
# Do you want to choose an other product, 1 - yes, 0 - no: 1
#
# Please enter a product you would like to purchase: hat
#
# Please enter a number of hats you would like to purchase: 2
# ValueError: Sorry, amount of items in store is not sufficient.
#
# Please enter a number of hats you would like to purchase: 1
# Added
#
# Do you want to choose an other product, 1 - yes, 0 - no: 0
#
# Enter a price for one bag: 2
#
# Enter a price for one hat: 2
#
#
# Total price: 4
#
#
#
# Total number of products ordered:  2
# Percentage of unique products ordered:  66.67
#
#
#
# Updated inventory:
# {'hat': 0, 'key': 2, 'bag': 2}
